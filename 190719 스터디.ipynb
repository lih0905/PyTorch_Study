# %%
import torch

# %%
torch.cuda.is_available()
# Out:
# True

# %%
x = torch.empty(5,3)
print(x)
# Out:
# tensor([[2.5758e-36, 0.0000e+00, 3.3631e-44],
#         [0.0000e+00,        nan, 0.0000e+00],
#         [1.1578e+27, 1.1362e+30, 7.1547e+22],
#         [4.5828e+30, 1.2121e+04, 7.1846e+22],
#         [9.2198e-39, 0.0000e+00, 0.0000e+00]])

# %%
torch.cuda.is_available()
# Out:
# True
